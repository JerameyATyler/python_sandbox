# %% [markdown]
# # Cepbimo - Python

# %% [markdown]
# ## Running the code

# %% [markdown]
# Executing the `run()` function will start the model.

# %%
from run import run

run()
# Out:
# C:\Users\Jeram\Desktop\pythonCepbimo\MixTracks.py:21: ComplexWarning: Casting complex values to real discards the imaginary part
#   y[:, i] = ax + bx
# C:\Users\Jeram\Desktop\pythonCepbimo\MixTracks.py:21: ComplexWarning: Casting complex values to real discards the imaginary part
#   y[:, i] = ax + bx
# C:\Users\Jeram\Desktop\pythonCepbimo\MixTracks.py:21: ComplexWarning: Casting complex values to real discards the imaginary part
#   y[:, i] = ax + bx
# C:\Users\Jeram\Desktop\pythonCepbimo\MixTracks.py:21: ComplexWarning: Casting complex values to real discards the imaginary part
#   y[:, i] = ax + bx
# C:\Users\Jeram\Desktop\pythonCepbimo\MixTracks.py:21: ComplexWarning: Casting complex values to real discards the imaginary part
#   y[:, i] = ax + bx
